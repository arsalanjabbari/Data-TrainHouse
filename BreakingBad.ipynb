# %%
import kagglehub
import pandas as pd

# %%
# Download latest version
path = kagglehub.dataset_download("parthhhpanchal/breaking-bad-datasets")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 12.0k/12.0k [00:00<00:00, 198kB/s]
# Extracting files...
# Path to dataset files: C:\Users\Arsalan\.cache\kagglehub\datasets\parthhhpanchal\breaking-bad-datasets\versions\1

# %%
characters_df = pd.read_csv("C:\\Users\\Arsalan\\.cache\\kagglehub\\datasets\\parthhhpanchal\\breaking-bad-datasets\\versions\\1\\characters.csv")
deaths_df = pd.read_csv("C:\\Users\\Arsalan\\.cache\\kagglehub\\datasets\\parthhhpanchal\\breaking-bad-datasets\\versions\\1\\deaths.csv")
episodes_df = pd.read_csv("C:\\Users\\Arsalan\\.cache\\kagglehub\\datasets\\parthhhpanchal\\breaking-bad-datasets\\versions\\1\\episodes.csv")
quotes_df = pd.read_csv("C:\\Users\\Arsalan\\.cache\\kagglehub\\datasets\\parthhhpanchal\\breaking-bad-datasets\\versions\\1\\quotes.csv")

# %% [markdown]
# 🧠 1️⃣ “The Descent Into Heisenberg” — Moral Corruption Index
# Goal:
#
# Quantify Walter White’s transformation into Heisenberg.
#
# Main entity:
# Walter White
#
# Build a “Corruption Score” per season:
#
# Combine:
#
# - Number of kills (direct/indirect)
#
# - % violent quotes
#
# - Ego-related words (from quotes)
#
# - Manipulative interactions
#
# - Criminal network growth
#
# Then:
# Plot corruption score vs season.
#
# 🔥 Deliverable:
# A graph showing the exact point where Walter becomes irredeemable.
#
# ☠️ 2️⃣ Survival Analysis of Breaking Bad Characters
#
# Treat it like medical survival analysis.
#
# Main character reference:
# Gustavo Fring
#
# Method:
#
# - Use deaths_df
#
# - Create “time-to-death” variable (season or episode number)
#
# - Apply Kaplan–Meier survival curves
#
# Questions:
#
# - Are drug dealers more likely to die early?
#
# - Do law enforcement characters survive longer?
#
# - Does screen time increase survival probability?
#
# 🔥 Advanced twist:
# Cox proportional hazards model with:
#
# - Role (law/crime/civilian)
#
# - Ego score (from quotes)
#
# - Network centrality
#
# 🗣 3️⃣ Quote Sentiment vs Character Fate
#
# Use NLP on quotes_df.
#
# Compare:
#
# - Sentiment trajectory per character
#
# - Toxicity / aggression over time
#
# - Dominance language frequency
#
# Compare:
# Jesse Pinkman
# vs
# Skyler White
#
# Hypothesis:
# Characters who become darker linguistically die sooner.
#
# 🔥 Visual:
# Sentiment over time by character.
#
# 🔗 4️⃣ Criminal Network Graph Analysis (THIS IS ELITE)
#
# Build a network:
#
# Nodes:
#
# - Characters
#
# Edges:
#
# - Shared episode
#
# - Quote interaction
#
# - Co-appearance in deaths
#
# Measure:
#
# - Betweenness centrality
#
# - Influence
#
# - Power structure evolution
#
# Watch how the network shifts:
#
# - Pre-Saul Goodman
#
# - Post-Gus death
#
# - Final season fragmentation
#
# 🔥 Deliverable:
# Animated network evolution over seasons.
#
# This screams data scientist.
#
# 🩸 5️⃣ Kill Chain & Violence Escalation Model
#
# From deaths_df:
#
# - Who kills whom?
#
# - Indirect vs direct responsibility?
#
# Build:
#
# - Kill graph
#
# - Violence propagation chains
#
# Questions:
#
# - Is Walter the central violence amplifier?
#
# - Who indirectly causes the most deaths?
#
# 🔥 Metric:
# “Violence Amplification Factor (VAF)”
#
# 🧪 6️⃣ Dialogue Complexity vs Intelligence
#
# Test:
# Do “smarter” characters speak more complex language?
#
# Use:
#
# - Vocabulary diversity
#
# - Sentence length
#
# - Shannon entropy
#
# - Lexical richness
#
# Compare:
# Walter White
# Hank Schrader
# Jesse Pinkman
#
# Plot linguistic sophistication index.
#
# 📈 7️⃣ Predicting Death: Can You See It Coming?
#
# Build a classifier:
#
# Target:
#
# - Dies (1/0)
#
# Features:
#
# - Criminal involvement
#
# - Quote aggression score
#
# - Network centrality
#
# - Screen time
#
# - Season first appearance
#
# Train:
#
# - Logistic regression
#
# - Random forest
#
# - XGBoost
#
# 🔥 Output:
# Probability of death for every character.
#
# Then test:
# Was Gus statistically doomed?
#
# 🎭 8️⃣ Ego vs Empathy Trajectory Model
#
# Create two NLP indices:
#
# - Ego index (I, me, my dominance words)
#
# - Empathy index (family, sorry, care, etc.)
#
# Track per season.
#
# Hypothesis:
# Empathy drops → mortality increases.
#
# 🧨 9️⃣ The “Chaos Theory” of Breaking Bad
#
# Measure:
#
# - Episode-level violence density
#
# - Death frequency
#
# - Quote negativity
#
# - Narrative entropy
#
# Find:
# Which episode is peak chaos?
#
# Probably around:
# Breaking Bad
#
# Prove it statistically.
