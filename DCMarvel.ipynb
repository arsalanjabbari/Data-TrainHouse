# %%
import kagglehub
import pandas as pd

# %%
# Download latest version
path = kagglehub.dataset_download("thedevastator/evolving-features-of-superheroes-and-supervillai")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Arsalan\.cache\kagglehub\datasets\thedevastator\evolving-features-of-superheroes-and-supervillai\versions\2

# %%
characters_df = pd.read_csv("C:\\Users\\Arsalan\\.cache\\kagglehub\\datasets\\thedevastator\\evolving-features-of-superheroes-and-supervillai\\versions\\2\\characters_stats.csv")

# %%
movies_df = pd.read_csv("C:\\Users\\Arsalan\\.cache\\kagglehub\\datasets\\thedevastator\\evolving-features-of-superheroes-and-supervillai\\versions\\2\\marvelvsdc.csv")

# %% [markdown]
# 1️⃣ “What Makes a Box Office Superhero?”
#
# Goal: Predict movie success based on character traits.
#
# 🔥 Idea
#
# Merge characters_df (powers, alignment, intelligence, strength, etc.) with movies_df (budget, box office, rating).
#
# Questions you can answer:
#
# -   Do heroes or villains drive more revenue?
#
# -   Do characters with more powers correlate with higher box office?
#
# -   Does intelligence > strength matter for movie ratings?
#
# -   Are team-based movies more profitable?
#
# 💡 Advanced Twist
#
# -   Build a regression model to predict box office revenue.
#
# -   Use feature importance to see what matters most.
#
# -   Compare Marvel vs DC performance: Marvel Comics / DC Comics

# %% [markdown]
# 2️⃣ Superpower Network Analysis (Very Cool Visually)
# 🔥 Idea
#
# Create a network graph of powers:
#
# -   Nodes = characters
#
# -   Edges = shared powers
#
# Then:
#
# -   Detect clusters (e.g., telepaths, speedsters, tech geniuses)
#
# -   Identify “most versatile” characters
#
# -   See if some powers frequently co-occur
#
# 💡 Advanced Twist
#
# Use centrality metrics:
#
# -   Who is the “most connected” character?
#
# -   Is there a power that dominates the universe?
#
# This makes for a GREAT interactive visualization project.

# %% [markdown]
# 3️⃣ Build a “Superhero Archetype” Model
#
# Use clustering (KMeans / Hierarchical) on:
#
# -   Strength
#
# -   Speed
#
# -   Durability
#
# -   Intelligence
#
# -   Power count
#
# 🔥 Result:
#
# Discover hidden archetypes like:
#
# -   “God-tier cosmic beings”
#
# -   “Street-level vigilantes”
#
# -   “Tech-based heroes”
#
# -   “Mutant powerhouses”
#
# Then check: Which archetype makes more successful movies?

# %% [markdown]
# 4️⃣ Bias & Representation Analysis (Very Impactful)
#
# Analyze:
#
# -   Gender distribution
#
# -   Alignment (hero/villain/antihero)
#
# -   Power level differences
#
# -   Screen time vs box office
#
# Questions:
#
# -   Are female characters underpowered statistically?
#
# -   Are villains more likely to have higher intelligence?
#
# -   Does diversity correlate with movie rating?
#
# This makes a strong storytelling project.

# %% [markdown]
# 5️⃣ “Build the Perfect Movie Team” Optimizer 🧠
#
# Treat it like a constrained optimization problem:
#
# Goal:
# Maximize predicted box office revenue
# Subject to:
#
# -   Budget constraint
#
# -   At least 1 female character
#
# -   At least 1 high-intelligence character
#
# -   Power diversity requirement
#
# Use:
#
# -   Linear programming
#
# -   Genetic algorithms
#
# This is next-level cool.

# %% [markdown]
# 6️⃣ Hero vs Villain Power Gap Study
#
# Are villains statistically stronger than heroes?
#
# Test:
#
# -   Mean strength difference
#
# -   Speed difference
#
# -   Intelligence difference
#
# Then compare:
#
# -   Avengers: Endgame
#
# -   Justice League
#
# Do stronger villains → bigger box office?

# %% [markdown]
# 7️⃣ Power Evolution Over Time
#
# If your movies_df has release year:
#
# Analyze:
#
# -   Are characters getting stronger over time?
#
# -   Has average intelligence increased?
#
# -   Are newer movies more team-focused?
#
# Visualize: Strength vs Year trendlines.

# %% [markdown]
# 8️⃣ Build a Superhero Recommendation System
#
# If someone liked:
#
# -   The Dark Knight
# Recommend:
#
# -   Similar characters based on traits.
#
# You can use:
#
# -   Cosine similarity
#
# -   Feature embeddings
#
# -   Matrix factorization

# %% [markdown]
# 9️⃣ Create a “Cinematic Power Index” (Original Concept)
# Create a custom index like:
# ```
# CPI = (0.3 * strength + 0.2 * intelligence + 0.2 * speed + 0.3 * power_count)
# ```
#
# Then:
#
# -   Rank all characters
#
# -   Compare CPI vs Box Office
#
# -   Compare Marvel vs DC distributions
#
# Make it visually dramatic.

# %% [markdown]
# 🔟 Predict Franchise Longevity
#
# Can you predict:
#
# -   Number of sequels
#
# -   Franchise lifetime revenue
#
# -   Character recurrence frequency
#
# Based on:
#
# -   Initial movie success
#
# -   Character power level
#
# -   Alignment
