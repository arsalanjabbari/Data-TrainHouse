# %%
import pandas as pd
import kagglehub

# %%
# Download latest version
path = kagglehub.dataset_download("mylesoneill/game-of-thrones")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 66.1k/66.1k [00:00<00:00, 208kB/s]
# Extracting files...
# Path to dataset files: C:\Users\Arsalan\.cache\kagglehub\datasets\mylesoneill\game-of-thrones\versions\1

# %%
battles = pd.read_csv("C:\\Users\\Arsalan\\.cache\\kagglehub\\datasets\\mylesoneill\\game-of-thrones\\versions\\1\\battles.csv")
character_deaths = pd.read_csv("C:\\Users\\Arsalan\\.cache\\kagglehub\\datasets\\mylesoneill\\game-of-thrones\\versions\\1\\character-deaths.csv")
character_predictions = pd.read_csv("C:\\Users\\Arsalan\\.cache\\kagglehub\\datasets\\mylesoneill\\game-of-thrones\\versions\\1\\character-predictions.csv")

# %%
character_predictions.head(15)
# Out:
#     S.No  actual  pred  alive   plod                  name  \
# 0      1       0     0  0.054  0.946  Viserys II Targaryen
# 1      2       1     0  0.387  0.613           Walder Frey
# 2      3       1     0  0.493  0.507          Addison Hill
# 3      4       0     0  0.076  0.924           Aemma Arryn
# 4      5       1     1  0.617  0.383        Sylva Santagar
# 5      6       1     0  0.021  0.979      Tommen Baratheon
# 6      7       0     0  0.014  0.986      Valarr Targaryen
# 7      8       0     0  0.036  0.964   Viserys I Targaryen
# 8      9       0     1  0.724  0.276               Wilbert
# 9     10       1     0  0.391  0.609        Wilbert Osgrey
# 10    11       0     0  0.167  0.833                  Will
# 11    12       1     1  0.985  0.015         Will (orphan)
# 12    13       1     1  0.813  0.187         Will (squire)
# 13    14       1     1  0.747  0.253      Will (Standfast)
# 14    15       1     1  0.705  0.295           Will (Treb)
#
# ...
